# %%
from logging import getLogger
import os
import json
import pandas as pd
import time, datetime
import torch

# %% [markdown]
# ### 데이터 로드

# %%
train_data = pd.read_csv('../data/train_data.csv')
test_data  = pd.read_csv('../data/test_data.csv')

# %% [markdown]
# 데이터 통합
# - GNN에서 학습되지 않은 노드에 대해 계산 할 수 없음
# - 기존 데이터셋에서 테스트 데이터셋의 사용자는 학습 데이터셋에 포함되어 있지 않음
# - 이에 따라 모든 데이터를 통합하여 사용하도록 함

# %%
data = pd.concat([train_data, test_data])
data = data.sort_values(by=['userID', 'Timestamp']).reset_index(drop=True)

# %% [markdown]
# ### 데이터 구성
#
# - 데이터는 학습 데이터셋과 테스트 데이터셋으로 구분되어 있다.
# - 각 데이터에는 userID, assessmentItemID, testId, answerCode, Timestamp, KnowledgeTag의 정보가 있다.
# - 여기서 assessmentItemID는 문제의 고유 ID이며, answerCode는 사용자가 해당 문제의 정답을 맞췄는지 여부로, 맞췄으면 1, 틀렸으면 0으로 표기된다.
# - 기본적인 협업 필터링 적용을 위해 본 실습에서는 userID, assessmentItemID, answerCode만을 사용한다.

# %%
userid, itemid = list(set(data.userID)), list(set(data.assessmentItemID))
n_user, n_item = len(userid), len(itemid)

print(f"Train dataset")
display(data.head(5))
print(f" Num. Users    : {n_user}")
print(f" Max. UserID   : {max(userid)}")
print(f" Num. Items    : {n_item}")
print(f" Num. Records  : {len(train_data)}")
# Out:
# Train dataset
#    userID assessmentItemID      testId  answerCode            Timestamp  \
# 0       0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1       0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2       0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3       0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4       0       A060001005  A060000001           1  2020-03-24 00:17:36
#
#    KnowledgeTag
# 0          7224
# 1          7225
# 2          7225
# 3          7225
# 4          7225
#  Num. Users    : 7442
#  Max. UserID   : 7441
#  Num. Items    : 9454
#  Num. Records  : 2266586

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# 중복 레코드 제거
#  - RS 모델에서는 시간에 따른 변화를 고려하지 않기 때문에 최종 성적만을 바탕으로 평가한다.
#  - 사용자+문제항목을 Unique key로 하여 최종 레코드만을 보존하고 나머지 제거한다.

# %%
data.drop_duplicates(subset = ["userID", "assessmentItemID"], 
                     keep = "last", inplace = True)

# %% [markdown]
# 평가 항목 제거
# - 테스트 데이터셋에서 answerCode가 -1인 항목은 최종 평가시 사용되는 항목으로 여기에선 사용할 수 없다.
# - 아래 결과에서와 같이 User, Item 수는 변화 없이 총 레코드 수만 변한다.

# %%
data_old = data.copy()
n_user_old, n_item_old = n_user, n_item

data  = data[data.answerCode>=0].copy()

userid, itemid = list(set(data.userID)), list(set(data.assessmentItemID))
n_user, n_item = len(userid), len(itemid)

display(data.tail(5))
print(f" Num. Users    : {n_user}->{n_user}")
print(f" Max. UserID   : {max(userid)}")
print(f" Num. Items    : {n_item}->{n_item}")
print(f" Num. Records  : {len(data_old)}->{len(data)}")
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2526699    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag
# 2526695           438
# 2526696          8836
# 2526697          8836
# 2526698          8836
# 2526699          8836
#  Num. Users    : 7442->7442
#  Max. UserID   : 7441
#  Num. Items    : 9454->9454
#  Num. Records  : 2476706->2475962

# %%
len(data)
#2474941
# Out:
# 2475962

# %%
data[data['userID']==0]
# Out:
#      userID assessmentItemID      testId  answerCode            Timestamp  \
# 0         0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1         0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2         0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3         0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4         0       A060001005  A060000001           1  2020-03-24 00:17:36
# ..      ...              ...         ...         ...                  ...
# 740       0       A080129002  A080000129           1  2020-12-23 03:35:54
# 741       0       A080129003  A080000129           0  2020-12-23 03:37:20
# 742       0       A080129004  A080000129           1  2020-12-23 03:38:43
# 743       0       A080129005  A080000129           0  2020-12-23 03:40:14
# 744       0       A080129006  A080000129           0  2020-12-23 03:40:19
#
#      KnowledgeTag
# 0            7224
# 1            7225
# 2            7225
# 3            7225
# 4            7225
# ..            ...
# 740          2723
# 741          2725
# 742          2725
# 743          2725
# 744          2725
#
# [745 rows x 6 columns]

# %%
data[data['userID']==1]
# Out:
#       userID assessmentItemID      testId  answerCode            Timestamp  \
# 745        1       A040013001  A040000013           1  2020-01-06 08:40:43
# 746        1       A040013002  A040000013           1  2020-01-06 08:43:46
# 747        1       A040013003  A040000013           1  2020-01-06 08:44:29
# 748        1       A040013004  A040000013           1  2020-01-06 08:46:13
# 749        1       A040013005  A040000013           0  2020-01-06 08:49:45
# ...      ...              ...         ...         ...                  ...
# 1673       1       A090074004  A090000074           1  2020-11-13 02:42:08
# 1674       1       A090074002  A090000074           1  2020-11-13 02:44:34
# 1675       1       A090074003  A090000074           1  2020-11-13 02:45:04
# 1676       1       A090074005  A090000074           1  2020-11-13 02:46:38
# 1677       1       A090074006  A090000074           1  2020-11-13 02:47:20
#
#       KnowledgeTag
# 745           2048
# 746           2048
# 747           2047
# 748           2047
# 749           2047
# ...            ...
# 1673         10196
# 1674          4243
# 1675          4243
# 1676          2648
# 1677          2648
#
# [879 rows x 6 columns]

# %% [markdown]
# # Augmentation

# %% [markdown]
# 평가 항목 신규 생성
# - 남은 테스트 항목 중, 각 사용자별 최종 레코드를 새로운 평가 항목으로 정한다.

# %%
eval_data = data.copy()
eval_data.drop_duplicates(subset = ["userID"],
                     keep = "last", inplace = True)
display(eval_data.head(5))
display(eval_data.tail(5))
print(f" Num. Records  : {len(eval_data)}")
# Out:
#       userID assessmentItemID      testId  answerCode            Timestamp  \
# 744        0       A080129006  A080000129           0  2020-12-23 03:40:19
# 1677       1       A090074006  A090000074           1  2020-11-13 02:47:20
# 1953       2       A050139007  A050000139           0  2020-10-20 11:32:26
# 2988       3       A050133007  A050000133           0  2020-10-26 13:13:11
# 3659       4       A070146007  A070000146           1  2020-12-27 02:47:31
#
#       KnowledgeTag
# 744           2725
# 1677          2648
# 1953           428
# 2988          5289
# 3659          9080
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526643    7437       A060003007  A060000003           0  2020-05-22 01:53:49
# 2526659    7438       A030188005  A030000188           1  2020-10-19 10:28:29
# 2526674    7439       A040130004  A040000130           1  2020-10-14 23:09:31
# 2526690    7440       A030197005  A030000197           0  2020-10-21 08:33:20
# 2526699    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag
# 2526643          7226
# 2526659          1934
# 2526674          8244
# 2526690          1984
# 2526699          8836
#  Num. Records  : 7442

# %% [markdown]
# 평가 항목을 테스트 항목에서 제거한다.

# %%
data1 = data.drop(index=eval_data.index)
display(data1.tail())
print(f" Num. Records  : {len(data1)}")
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526694    7441       A030071004  A030000071           0  2020-06-05 06:49:57
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
#
#          KnowledgeTag
# 2526694           438
# 2526695           438
# 2526696          8836
# 2526697          8836
# 2526698          8836
#  Num. Records  : 2468520

# %% [markdown]
# data1 => Data에서 마지막 항 제거된 데이터

# %% [markdown]
# ## 2번 적용

# %%
eval_data1 = data1.copy()
eval_data1.drop_duplicates(subset = ["userID"],
                     keep = "last", inplace = True)
display(eval_data1.head(5))
display(eval_data1.tail(5))
print(f" Num. Records  : {len(eval_data1)}")
# Out:
#       userID assessmentItemID      testId  answerCode            Timestamp  \
# 743        0       A080129005  A080000129           0  2020-12-23 03:40:14
# 1676       1       A090074005  A090000074           1  2020-11-13 02:46:38
# 1952       2       A050139006  A050000139           0  2020-10-20 11:32:20
# 2987       3       A050133006  A050000133           1  2020-10-26 13:12:52
# 3658       4       A070146006  A070000146           1  2020-12-27 02:46:51
#
#       KnowledgeTag
# 743           2725
# 1676          2648
# 1952           428
# 2987          5288
# 3658          9079
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526642    7437       A060003006  A060000003           1  2020-05-22 01:53:45
# 2526658    7438       A030188004  A030000188           1  2020-10-19 10:26:36
# 2526673    7439       A040130003  A040000130           1  2020-10-14 23:08:02
# 2526689    7440       A030197004  A030000197           0  2020-10-21 08:33:17
# 2526698    7441       A040165003  A040000165           1  2020-08-21 01:07:36
#
#          KnowledgeTag
# 2526642          7226
# 2526658          1934
# 2526673          8244
# 2526689          1984
# 2526698          8836
#  Num. Records  : 7442

# %%
data2 = data1.drop(index=eval_data1.index)
display(data2.tail())
print(f" Num. Records  : {len(data2)}")
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526693    7441       A030071003  A030000071           1  2020-06-05 06:49:23
# 2526694    7441       A030071004  A030000071           0  2020-06-05 06:49:57
# 2526695    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697    7441       A040165002  A040000165           1  2020-08-21 01:06:50
#
#          KnowledgeTag
# 2526693           438
# 2526694           438
# 2526695           438
# 2526696          8836
# 2526697          8836
#  Num. Records  : 2461078

# %%
2461078+7442
# Out:
# 2468520

# %% [markdown]
# ## 합치기

# %%
data1['userID'] = data1['userID'] +max(data['userID'])
data2['userID'] = data2['userID'] +max(data1['userID'])

# %%
data1.head()
# Out:
#    userID assessmentItemID      testId  answerCode            Timestamp  \
# 0    7441       A060001001  A060000001           1  2020-03-24 00:17:11
# 1    7441       A060001002  A060000001           1  2020-03-24 00:17:14
# 2    7441       A060001003  A060000001           1  2020-03-24 00:17:22
# 3    7441       A060001004  A060000001           1  2020-03-24 00:17:29
# 4    7441       A060001005  A060000001           1  2020-03-24 00:17:36
#
#    KnowledgeTag
# 0          7224
# 1          7225
# 2          7225
# 3          7225
# 4          7225

# %%
datasum = pd.concat([data,data1,data2])

# %%
datasum.tail()
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 2526693   22323       A030071003  A030000071           1  2020-06-05 06:49:23
# 2526694   22323       A030071004  A030000071           0  2020-06-05 06:49:57
# 2526695   22323       A030071005  A030000071           0  2020-06-05 06:50:21
# 2526696   22323       A040165001  A040000165           1  2020-08-21 01:06:39
# 2526697   22323       A040165002  A040000165           1  2020-08-21 01:06:50
#
#          KnowledgeTag
# 2526693           438
# 2526694           438
# 2526695           438
# 2526696          8836
# 2526697          8836

# %% [markdown]
# # Augmentation 일반화 (n번 돌려버리기)

# %%
# 데이터 몇번 증강하실? (데이터는 약 n+1배 됨)
n = 2

# %%
# 원래 데이터 개수
len(data)
# Out:
# 2476706

# %%
datasum = data.copy()
eval_data = pd.DataFrame()
data1 = data.copy()
print(max(data1['userID']))
for i in range(n):
    print('-'*10,f'epoch{i+1}','-'*10)
    # eval_data1 : user마다 마지막 값들을 저장
    eval_data1 = data1.copy()
    eval_data1.drop_duplicates(subset = ["userID"],
                        keep = "last", inplace = True)
    print(f" Drop counts   : {len(eval_data1)}")

    # data2: 원래 데이터에서 마지막 값들을 drop 해줌
    data2 = data1.drop(index=eval_data1.index)
    print(f" length counts : {len(data2)}")

    # 새로 augment 된 데이터 userID 안겹치게, 이전 최고 id값 더해주기
    data2['userID'] = data2['userID'] +7442 
    print(f" last user num : {max(data2['userID'])}")
        
    # concat 조져버리기
    datasum = pd.concat([datasum,data2])
    eval_data = pd.concat([eval_data,eval_data1])
    data1 = data2.copy()
print('-'*28)
# Out:
# 7441
# ---------- epoch1 ----------
#  Drop counts   : 7442
#  length counts : 2469264
#  last user num : 14883
# ---------- epoch2 ----------
#  Drop counts   : 7442
#  length counts : 2461822
#  last user num : 22325
# ----------------------------

# %%
len(datasum)
# Out:
# 7407792

# %%
# CSV 로 저장해 버리기
datasum.to_csv('new_train.csv',index=False)

# 혹시 몰라 넣은 evaluation data
# eval_data.to_csv('new_eval.csv',index=False)
